# %%
import torch


val = torch.tensor([[1,1,4],[5,7,8]]).float()

print(f'val.mean(0,True)={val.mean(0,True)}')
print(val / val.mean(0,True))
print(f'val.mean(1,True)={val.mean(1,True)}')
# Out:
# val.mean(0,True)=tensor([[3., 4., 6.]])
# tensor([[0.3333, 0.2500, 0.6667],
#         [1.6667, 1.7500, 1.3333]])
# val.mean(1,True)=tensor([[2.0000],
#         [6.6667]])

# %%
import torch

val_1 = torch.tensor([[1,1,4],[5,7,8], [4,6,2]]).float()
val_2 = torch.tensor([[1,1,4,1],[5,7,8,1], [4,6,2,1]]).float()
val_3 = torch.cat([val_1, val_2])
print(val_3)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 5
#       3 val_1 = torch.tensor([[1,1,4],[5,7,8], [4,6,2]]).float()
#       4 val_2 = torch.tensor([[1,1,4,1],[5,7,8,1], [4,6,2,1]]).float()
# ----> 5 val_3 = torch.cat([val_1, val_2])
#       6 print(val_3)
#
# RuntimeError: Sizes of tensors must match except in dimension 0. Expected size 3 but got size 4 for tensor number 1 in the list.
